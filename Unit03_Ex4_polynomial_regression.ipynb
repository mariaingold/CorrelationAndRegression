# %% [markdown]
# # POLYNOMIAL REGRESSION
#
# - x: independent variable
# - y: dependent variable
# - Regression analysis relationship curve is an nth degree polynomial
#
# ## Modifications to UoEO code
# - Moved libraries to top to comply with PEP 8 standard.
# - Created variable to change speed
# - Created graph with intersect line of time_pass (x) to speed (y)

# %% [markdown]
# ## Libraries

# %%
import numpy                          # numerical operations
import matplotlib.pyplot as plt       # visualise data and model
from sklearn.metrics import r2_score  # Machine Learning R-squared function

# %% [markdown]
# ## Cars passing tollbooth at time of day (x) and speed (y)

# %% [markdown]
# 18 cars passing a certain tollboth at different time of the day (x) with different speed (y)

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

#NumPy has a method that lets us make a polynomial model
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

#specify how the line will display, we start at position 1, and end at position 22
myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# ## R-squared
#
# Measures relationship between x and y.
#  - 0: no relationship
#  - 1: 100% related

# %% [markdown]
# It is important to know how well the relationship between the values of the x- and y-axis is, if there are no relationship the polynomial regression can not be used to predict anything.
#
# The relationship is measured with a value called the r-squared.
#
# The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related

# %%
print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451026

# %% [markdown]
# ## Predict Future Values

# %% [markdown]
# Let us try to predict the speed of a car that passes the tollbooth at around 17 P.M

# %%
time_pass = 17

# Calculate speed (y) at time_pass (x):
speed = mymodel(time_pass)  # Calculate the speed at x = time_pass
print(f"Speed:", speed)

# Plot the scatter, line and intersect:
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.plot([time_pass, time_pass], [plt.ylim()[0], speed], 'k--')  # Vertical line to x-axis
plt.plot([plt.xlim()[0], time_pass], [speed, speed], 'k--')  # Horizontal line to y-axis

plt.show()
# Out:
# Speed: 88.87331269698001
